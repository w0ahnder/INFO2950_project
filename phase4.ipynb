# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import duckdb

# %%
income_df = pd.read_csv("data/income.csv")
income_df.iloc[:, 20:].head(5)
# Out:
#        Unnamed: 20     Unnamed: 21      Unnamed: 22     Unnamed: 23  \
# 0              NaN             NaN              NaN             NaN
# 1              NaN             NaN              NaN             NaN
# 2              NaN             NaN              NaN             NaN
# 3              NaN       2010 (37)              NaN       2009 (36)
# 4  Standard\nerror  Median\nincome  Standard\nerror  Median\nincome
#
#        Unnamed: 24     Unnamed: 25      Unnamed: 26     Unnamed: 27  \
# 0              NaN             NaN              NaN             NaN
# 1              NaN             NaN              NaN             NaN
# 2              NaN             NaN              NaN             NaN
# 3              NaN            2008              NaN            2007
# 4  Standard\nerror  Median\nincome  Standard\nerror  Median\nincome
#
#        Unnamed: 28     Unnamed: 29  ...     Unnamed: 65      Unnamed: 66  \
# 0              NaN             NaN  ...             NaN              NaN
# 1              NaN             NaN  ...             NaN              NaN
# 2              NaN             NaN  ...             NaN              NaN
# 3              NaN            2006  ...            1988              NaN
# 4  Standard\nerror  Median\nincome  ...  Median\nincome  Standard\nerror
#
#       Unnamed: 67      Unnamed: 68     Unnamed: 69      Unnamed: 70  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3       1987 (21)              NaN            1986              NaN
# 4  Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
#
#       Unnamed: 71      Unnamed: 72     Unnamed: 73      Unnamed: 74
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3       1985 (20)              NaN       1984 (19)              NaN
# 4  Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
#
# [5 rows x 55 columns]

# %%
income_df.drop(columns={'Unnamed: 12','Unnamed: 10','Unnamed: 8',\
                        'Unnamed: 6', 'Unnamed: 4', 'Unnamed: 2' , 'Unnamed: 3',\
                          'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20',\
                            'Unnamed: 22', 'Unnamed: 24', 'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30',
                            'Unnamed: 32', 'Unnamed: 34', 'Unnamed: 36',\
                            'Unnamed: 38', 'Unnamed: 40', 'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46',\
                              'Unnamed: 48', 'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54',\
                                'Unnamed: 56', 'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62',\
                                  'Unnamed: 64', 'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70',\
                                    'Unnamed: 72', 'Unnamed: 74'}, inplace=True)
print(income_df.columns)
(income_df.iloc[3:, :]).head()
# Out:
# Index(['Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61',
#        'Unnamed: 1', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11',
#        'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 19',
#        'Unnamed: 21', 'Unnamed: 23', 'Unnamed: 25', 'Unnamed: 27',
#        'Unnamed: 29', 'Unnamed: 31', 'Unnamed: 33', 'Unnamed: 35',
#        'Unnamed: 37', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 43',
#        'Unnamed: 45', 'Unnamed: 47', 'Unnamed: 49', 'Unnamed: 51',
#        'Unnamed: 53', 'Unnamed: 55', 'Unnamed: 57', 'Unnamed: 59',
#        'Unnamed: 61', 'Unnamed: 63', 'Unnamed: 65', 'Unnamed: 67',
#        'Unnamed: 69', 'Unnamed: 71', 'Unnamed: 73'],
#       dtype='object')
#   Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 3                                              State
# 4                                                NaN
# 5                                      United States
# 6                                            Alabama
# 7                                             Alaska
#
#        Unnamed: 1      Unnamed: 5      Unnamed: 7      Unnamed: 9  \
# 3            2018            2017            2016            2015
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          63,179          61,372          59,039          56,516
# 6          49,936          51,113          47,221          44,509
# 7          68,734          72,231          75,723          75,112
#
#       Unnamed: 11     Unnamed: 13     Unnamed: 15     Unnamed: 17  \
# 3            2014       2013 (39)       2013 (38)            2012
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          53,657          53,585          51,939          51,017
# 6          42,278          47,320          41,381          43,464
# 7          67,629          72,472          61,137          63,648
#
#       Unnamed: 19  ...     Unnamed: 55     Unnamed: 57     Unnamed: 59  \
# 3            2011  ...       1993 (23)       1992 (22)            1991
# 4  Median\nincome  ...  Median\nincome  Median\nincome  Median\nincome
# 5          50,054  ...          31,241          30,636          30,126
# 6          42,590  ...          25,082          25,808          24,346
# 7          57,431  ...          42,931          41,802          40,612
#
#       Unnamed: 61     Unnamed: 63     Unnamed: 65     Unnamed: 67  \
# 3            1990            1989            1988       1987 (21)
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          29,943          28,906          27,225          26,061
# 6          23,357          21,284          19,948          19,734
# 7          39,298          36,006          33,103          33,233
#
#       Unnamed: 69     Unnamed: 71     Unnamed: 73
# 3            1986       1985 (20)       1984 (19)
# 4  Median\nincome  Median\nincome  Median\nincome
# 5          24,897          23,618          22,415
# 6          19,132          18,333          17,310
# 7          31,356          34,782          32,356
#
# [5 rows x 37 columns]

# %%
income_df = income_df.iloc[3:, :]
income_df.head()
# Out:
#   Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 3                                              State
# 4                                                NaN
# 5                                      United States
# 6                                            Alabama
# 7                                             Alaska
#
#        Unnamed: 1      Unnamed: 5      Unnamed: 7      Unnamed: 9  \
# 3            2018            2017            2016            2015
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          63,179          61,372          59,039          56,516
# 6          49,936          51,113          47,221          44,509
# 7          68,734          72,231          75,723          75,112
#
#       Unnamed: 11     Unnamed: 13     Unnamed: 15     Unnamed: 17  \
# 3            2014       2013 (39)       2013 (38)            2012
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          53,657          53,585          51,939          51,017
# 6          42,278          47,320          41,381          43,464
# 7          67,629          72,472          61,137          63,648
#
#       Unnamed: 19  ...     Unnamed: 55     Unnamed: 57     Unnamed: 59  \
# 3            2011  ...       1993 (23)       1992 (22)            1991
# 4  Median\nincome  ...  Median\nincome  Median\nincome  Median\nincome
# 5          50,054  ...          31,241          30,636          30,126
# 6          42,590  ...          25,082          25,808          24,346
# 7          57,431  ...          42,931          41,802          40,612
#
#       Unnamed: 61     Unnamed: 63     Unnamed: 65     Unnamed: 67  \
# 3            1990            1989            1988       1987 (21)
# 4  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5          29,943          28,906          27,225          26,061
# 6          23,357          21,284          19,948          19,734
# 7          39,298          36,006          33,103          33,233
#
#       Unnamed: 69     Unnamed: 71     Unnamed: 73
# 3            1986       1985 (20)       1984 (19)
# 4  Median\nincome  Median\nincome  Median\nincome
# 5          24,897          23,618          22,415
# 6          19,132          18,333          17,310
# 7          31,356          34,782          32,356
#
# [5 rows x 37 columns]

# %%
income_df.iloc[:, 5:]
# Out:
#         Unnamed: 11     Unnamed: 13     Unnamed: 15     Unnamed: 17  \
# 3              2014       2013 (39)       2013 (38)            2012
# 4    Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5            53,657          53,585          51,939          51,017
# 6            42,278          47,320          41,381          43,464
# 7            67,629          72,472          61,137          63,648
# ..              ...             ...             ...             ...
# 110          61,665          55,849          59,663          58,159
# 111          59,128          72,817          60,140          63,016
# 112             NaN             NaN             NaN             NaN
# 113             NaN             NaN             NaN             NaN
# 114             NaN             NaN             NaN             NaN
#
#         Unnamed: 19     Unnamed: 21     Unnamed: 23     Unnamed: 25  \
# 3              2011       2010 (37)       2009 (36)            2008
# 4    Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5            50,054          49,276          49,777          50,303
# 6            42,590          40,933          39,980          44,476
# 7            57,431          57,848          61,604          63,989
# ..              ...             ...             ...             ...
# 110          58,248          58,114          60,112          59,860
# 111          60,991          60,249          61,559          62,359
# 112             NaN             NaN             NaN             NaN
# 113             NaN             NaN             NaN             NaN
# 114             NaN             NaN             NaN             NaN
#
#         Unnamed: 27     Unnamed: 29  ...     Unnamed: 55     Unnamed: 57  \
# 3              2007            2006  ...       1993 (23)       1992 (22)
# 4    Median\nincome  Median\nincome  ...  Median\nincome  Median\nincome
# 5            50,233          48,201  ...          31,241          30,636
# 6            42,212          37,952  ...          25,082          25,808
# 7            62,993          56,418  ...          42,931          41,802
# ..              ...             ...  ...             ...             ...
# 110          62,253          64,536  ...          54,511          58,598
# 111          59,178          58,730  ...          50,523          53,146
# 112             NaN             NaN  ...             NaN             NaN
# 113             NaN             NaN  ...             NaN             NaN
# 114             NaN             NaN  ...             NaN             NaN
#
#         Unnamed: 59     Unnamed: 61     Unnamed: 63     Unnamed: 65  \
# 3              1991            1990            1989            1988
# 4    Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5            30,126          29,943          28,906          27,225
# 6            24,346          23,357          21,284          19,948
# 7            40,612          39,298          36,006          33,103
# ..              ...             ...             ...             ...
# 110          56,134          57,387          57,103          60,525
# 111          52,378          55,050          57,884          54,066
# 112             NaN             NaN             NaN             NaN
# 113             NaN             NaN             NaN             NaN
# 114             NaN             NaN             NaN             NaN
#
#         Unnamed: 67     Unnamed: 69     Unnamed: 71     Unnamed: 73
# 3         1987 (21)            1986       1985 (20)       1984 (19)
# 4    Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 5            26,061          24,897          23,618          22,415
# 6            19,734          19,132          18,333          17,310
# 7            33,233          31,356          34,782          32,356
# ..              ...             ...             ...             ...
# 110          55,913          57,970          51,879          47,882
# 111          58,502          51,673          49,279          54,976
# 112             NaN             NaN             NaN             NaN
# 113             NaN             NaN             NaN             NaN
# 114             NaN             NaN             NaN             NaN
#
# [112 rows x 32 columns]

# %%
income_df.rename(columns = {'Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61':'State',
                            'Unnamed: 1': '2018', 'Unnamed: 5': '2017',\
                            'Unnamed: 7': '2016', 'Unnamed: 9': '2015' , \
                                'Unnamed: 11': '2014', 'Unnamed: 13': '2013',\
                                   'Unnamed: 15': '2013', 'Unnamed: 17': '2012', 'Unnamed: 19': '2011', \
                                     'Unnamed: 21': '2010', 'Unnamed: 23': '2009', 'Unnamed: 25': '2008',\
                                         'Unnamed: 27': '2007', 'Unnamed: 29': '2006', 'Unnamed: 31': '2005',\
                                              'Unnamed: 33': '2004', 'Unnamed: 35': '2003', 'Unnamed: 37': '2002', 'Unnamed: 39': '2001',\
                                                  'Unnamed: 41': '2000', 'Unnamed: 43': '1999', 'Unnamed: 45': '1998', \
                                                      'Unnamed: 47': '1997', 'Unnamed: 49': '1996', 'Unnamed: 51': '1995',\
                                                          'Unnamed: 53': '1994', 'Unnamed: 55': '1993', 'Unnamed: 57': '1992',\
                                                              'Unnamed: 59': '1991', 'Unnamed: 61': '1990', 'Unnamed: 63': '1989'}, inplace=True)
income_df.rename(columns = {'Unnamed: 65': '1988', 'Unnamed: 67': '1987', 'Unnamed: 69': '1986', 'Unnamed: 71': '1985',\
                            'Unnamed: 73': '1984'}, inplace=True)
income_df.reset_index(inplace=True, drop= True)
income_df.head()
# Out:
#            State            2018            2017            2016  \
# 0          State            2018            2017            2016
# 1            NaN  Median\nincome  Median\nincome  Median\nincome
# 2  United States          63,179          61,372          59,039
# 3        Alabama          49,936          51,113          47,221
# 4         Alaska          68,734          72,231          75,723
#
#              2015            2014            2013            2013  \
# 0            2015            2014       2013 (39)       2013 (38)
# 1  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 2          56,516          53,657          53,585          51,939
# 3          44,509          42,278          47,320          41,381
# 4          75,112          67,629          72,472          61,137
#
#              2012            2011  ...            1993            1992  \
# 0            2012            2011  ...       1993 (23)       1992 (22)
# 1  Median\nincome  Median\nincome  ...  Median\nincome  Median\nincome
# 2          51,017          50,054  ...          31,241          30,636
# 3          43,464          42,590  ...          25,082          25,808
# 4          63,648          57,431  ...          42,931          41,802
#
#              1991            1990            1989            1988  \
# 0            1991            1990            1989            1988
# 1  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 2          30,126          29,943          28,906          27,225
# 3          24,346          23,357          21,284          19,948
# 4          40,612          39,298          36,006          33,103
#
#              1987            1986            1985            1984
# 0       1987 (21)            1986       1985 (20)       1984 (19)
# 1  Median\nincome  Median\nincome  Median\nincome  Median\nincome
# 2          26,061          24,897          23,618          22,415
# 3          19,734          19,132          18,333          17,310
# 4          33,233          31,356          34,782          32,356
#
# [5 rows x 37 columns]

# %%
income_df = income_df.iloc[3:54, :]
income_df.reset_index(inplace=True, drop = True)
#print(income_df.head())
income_df.head(7)
# Out:
#          State    2018    2017    2016    2015    2014    2013    2013  \
# 0      Alabama  49,936  51,113  47,221  44,509  42,278  47,320  41,381
# 1       Alaska  68,734  72,231  75,723  75,112  67,629  72,472  61,137
# 2      Arizona  62,283  61,125  57,100  52,248  49,254  52,611  50,602
# 3     Arkansas  49,781  48,829  45,907  42,798  44,922  39,376  39,919
# 4   California  70,489  69,759  66,637  63,636  60,487  60,794  57,528
# 5     Colorado  73,034  74,172  70,566  66,596  60,940  67,912  63,371
# 6  Connecticut  72,812  72,780  75,923  72,889  70,161  69,291  67,781
#
#      2012    2011  ...    1993    1992    1991    1990    1989    1988  \
# 0  43,464  42,590  ...  25,082  25,808  24,346  23,357  21,284  19,948
# 1  63,648  57,431  ...  42,931  41,802  40,612  39,298  36,006  33,103
# 2  47,044  48,621  ...  30,510  29,358  30,737  29,224  28,552  26,435
# 3  39,018  41,302  ...  23,039  23,882  23,435  22,786  21,433  20,172
# 4  57,020  53,367  ...  34,073  34,903  33,664  33,290  33,009  30,287
# 5  57,255  58,629  ...  34,488  32,484  31,499  30,733  26,806  26,214
# 6  64,247  65,415  ...  39,516  40,841  42,154  38,870  42,321  36,213
#
#      1987    1986    1985    1984
# 0  19,734  19,132  18,333  17,310
# 1  33,233  31,356  34,782  32,356
# 2  26,749  25,500  23,877  21,425
# 3  18,827  18,730  17,451  15,674
# 4  30,146  29,010  26,981  25,287
# 5  26,476  27,192  28,182  25,801
# 6  32,862  32,721  31,090  29,951
#
# [7 rows x 37 columns]

# %%
income_df.tail(7)
# Out:
#             State    2018    2017    2016    2015    2014    2013    2013  \
# 44           Utah  77,067  71,319  67,481  66,258  63,383  61,047  62,967
# 45        Vermont  70,066  63,805  60,837  59,494  60,708  65,513  54,842
# 46       Virginia  77,151  71,293  66,451  61,486  66,155  65,907  67,620
# 47     Washington  79,726  75,418  70,310  67,243  59,068  63,922  60,106
# 48  West Virginia  50,573  45,392  44,354  42,824  39,552  43,069  40,241
# 49      Wisconsin  62,629  63,451  59,817  55,425  58,080  51,726  55,258
# 50        Wyoming  62,539  57,837  57,829  60,925  55,690  67,441  55,700
#
#       2012    2011  ...    1993    1992    1991    1990    1989    1988  \
# 44  58,341  55,493  ...  35,786  34,251  28,016  30,142  30,717  26,313
# 45  55,582  51,862  ...  31,065  32,755  29,155  31,098  31,295  28,988
# 46  64,632  62,616  ...  36,433  38,198  36,137  35,073  34,118  32,648
# 47  62,187  56,850  ...  35,655  33,900  33,970  32,112  31,961  32,327
# 48  43,553  41,821  ...  22,421  20,271  23,147  22,137  21,677  19,353
# 49  53,079  52,058  ...  31,766  33,308  31,133  30,711  29,123  29,575
# 50  57,512  54,509  ...  29,442  30,209  29,050  29,460  29,521  26,419
#
#       1987    1986    1985    1984
# 44  26,529  26,281  25,238  23,057
# 45  25,415  24,599  26,000  22,578
# 46  29,996  29,715  28,429  26,525
# 47  27,319  26,881  24,000  25,017
# 48  17,207  16,464  15,983  16,843
# 49  26,369  26,430  23,246  20,743
# 50  27,590  23,559  22,081  23,816
#
# [7 rows x 37 columns]

# %%
'''for c in (income_df.columns.array)[1:]:
  income_df[c] = income_df[c].str.replace(',', '').astype(float)
income_df.dtypes
'''
income_df = income_df.replace(',', '', regex = True)
for c in (income_df.columns.array)[1:]:
  income_df[c] = income_df[c].astype(float)
#income_df.dtypes

# %% [markdown]
# ## Cleaning crime until 1979

# %%
#loading crime data
crime_df = pd.read_csv('data/crime.csv')
crime_df.iloc[:, 2:]
# Out:
#       Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 0     state_name  population  violent_crime   homicide  rape_legacy
# 1            NaN   220099000        1208030      21460        76390
# 2         Alaska      406000           1994         54          292
# 3        Alabama     3769000          15578        496         1037
# 4       Arkansas     2180000           7984        198          595
# ...          ...         ...            ...        ...          ...
# 2332         NaN   8,715,698         20,589        520          NaN
# 2333         NaN   7,812,880         27,909        373          NaN
# 2334         NaN   1,770,071          4,699         87          NaN
# 2335         NaN   5,910,955         17,057        283          NaN
# 2336         NaN     584,057          1,116         18          NaN
#
#         Unnamed: 7 Unnamed: 8          Unnamed: 9     Unnamed: 10 Unnamed: 11  \
# 0     rape_revised    robbery  aggravated_assault  property_crime    burglary
# 1              NaN     480700              629480        11041500     3327700
# 2              NaN        445                1203           23193        5616
# 3              NaN       4127                9918          144372       48517
# 4              NaN       1626                5565           70949       21457
# ...            ...        ...                 ...             ...         ...
# 2332         2,595      3,283              14,191         144,566      10,665
# 2333         2,917      6,416              18,203         225,535      37,583
# 2334           823        199               3,590          21,153       3,156
# 2335         2,156      2,285              12,333          71,929       7,619
# 2336           314         67                 717           8,585       1,185
#
#      Unnamed: 12          Unnamed: 13 Unnamed: 14
# 0        larceny  motor_vehicle_theft     caveats
# 1        6601000              1112800         NaN
# 2          15076                 2501         NaN
# 3          83791                12064         NaN
# 4          45267                 4225         NaN
# ...          ...                  ...         ...
# 2332     118,839               15,062         NaN
# 2333     134,730               53,222         NaN
# 2334      16,355                1,642         NaN
# 2335      54,374                9,936         NaN
# 2336       6,631                  769         NaN
#
# [2337 rows x 13 columns]

# %%
#see what the names of each column are without any edits to the csv
print(crime_df.columns)

#rename the columns we want with proper names
crime_df.rename(columns={
    'estimated_crimes_1979_2023': 'Year',
    'Unnamed: 1': 'State_Abbreviation',
    'Unnamed: 2': 'State_Name',
    'Unnamed: 3': 'Population',
    'Unnamed: 4': 'Violent_Crime',
    'Unnamed: 5': 'Homicide',
    'Unnamed: 6': 'Rape',
    'Unnamed: 7': 'Rape_Revised',
    'Unnamed: 8': 'Robbery',
    'Unnamed: 9': 'Aggravated_Assault',
    'Unnamed: 10': 'Property_Crime',
    'Unnamed: 11': 'Burglary',
    'Unnamed: 12': 'Larceny',
    'Unnamed: 13': 'Vehicle_Theft',

},inplace=True)

#drop columns that will not be used during the analysis
crime_df = crime_df.drop(columns=['Unnamed: 14'])
crime_df
# Out:
# Index(['estimated_crimes_1979_2023', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')
#       Year State_Abbreviation  State_Name  Population  Violent_Crime  \
# 0     year         state_abbr  state_name  population  violent_crime
# 1     1979                NaN         NaN   220099000        1208030
# 2     1979                 AK      Alaska      406000           1994
# 3     1979                 AL     Alabama     3769000          15578
# 4     1979                 AR    Arkansas     2180000           7984
# ...    ...                ...         ...         ...            ...
# 2332  2023                 VA         NaN   8,715,698         20,589
# 2333  2023                 WA         NaN   7,812,880         27,909
# 2334  2023                 WV         NaN   1,770,071          4,699
# 2335  2023                 WI         NaN   5,910,955         17,057
# 2336  2023                 WY         NaN     584,057          1,116
#
#       Homicide         Rape  Rape_Revised  Robbery  Aggravated_Assault  \
# 0     homicide  rape_legacy  rape_revised  robbery  aggravated_assault
# 1        21460        76390           NaN   480700              629480
# 2           54          292           NaN      445                1203
# 3          496         1037           NaN     4127                9918
# 4          198          595           NaN     1626                5565
# ...        ...          ...           ...      ...                 ...
# 2332       520          NaN         2,595    3,283              14,191
# 2333       373          NaN         2,917    6,416              18,203
# 2334        87          NaN           823      199               3,590
# 2335       283          NaN         2,156    2,285              12,333
# 2336        18          NaN           314       67                 717
#
#       Property_Crime  Burglary  Larceny        Vehicle_Theft
# 0     property_crime  burglary  larceny  motor_vehicle_theft
# 1           11041500   3327700  6601000              1112800
# 2              23193      5616    15076                 2501
# 3             144372     48517    83791                12064
# 4              70949     21457    45267                 4225
# ...              ...       ...      ...                  ...
# 2332         144,566    10,665  118,839               15,062
# 2333         225,535    37,583  134,730               53,222
# 2334          21,153     3,156   16,355                1,642
# 2335          71,929     7,619   54,374                9,936
# 2336           8,585     1,185    6,631                  769
#
# [2337 rows x 14 columns]

# %%
#dropping the first row (index 0) and reset the indexes.
# This way, I can turn the year from object to integer.
crime_df = crime_df.drop(index=0)

# %%
#if rape_Revised is na, take rape
na_rape_values = crime_df['Rape'].loc[crime_df['Rape_Revised'].isna()] #put this into rape_revised

crime_df['Rape_Revised'] = crime_df['Rape_Revised'].fillna(na_rape_values)

crime_df = crime_df.drop(columns = ['Rape'])

crime_df.rename(columns= {'Rape_Revised':'Rape'}, inplace=True)
crime_df.head()
# Out:
#    Year State_Abbreviation State_Name Population Violent_Crime Homicide  \
# 1  1979                NaN        NaN  220099000       1208030    21460
# 2  1979                 AK     Alaska     406000          1994       54
# 3  1979                 AL    Alabama    3769000         15578      496
# 4  1979                 AR   Arkansas    2180000          7984      198
# 5  1979                 AZ    Arizona    2450000         14528      219
#
#     Rape Robbery Aggravated_Assault Property_Crime Burglary  Larceny  \
# 1  76390  480700             629480       11041500  3327700  6601000
# 2    292     445               1203          23193     5616    15076
# 3   1037    4127               9918         144372    48517    83791
# 4    595    1626               5565          70949    21457    45267
# 5   1120    4305               8884         177977    48916   116976
#
#   Vehicle_Theft
# 1       1112800
# 2          2501
# 3         12064
# 4          4225
# 5         12085

# %%
# Reset the index
crime_df.reset_index(drop=True, inplace=True)

#making the year into an interger from an object
crime_df['Year']=crime_df['Year'].astype(int)

#shaping the data set so that we are only looking at years 2013 to 2018
crime_filtered_years = crime_df[(crime_df['Year'] >= 1979)]

# Drop rows where 'State_Abbreviation' or 'State_Name' is NaN
crime_filtered_years = crime_filtered_years.dropna(subset=['State_Abbreviation', 'State_Name'])
crime_filtered_years.reset_index(inplace=True, drop = True)
crime_filtered_years
# Out:
#       Year State_Abbreviation          State_Name Population Violent_Crime  \
# 0     1979                 AK              Alaska     406000          1994
# 1     1979                 AL             Alabama    3769000         15578
# 2     1979                 AR            Arkansas    2180000          7984
# 3     1979                 AZ             Arizona    2450000         14528
# 4     1979                 CA          California   22696000        184087
# ...    ...                ...                 ...        ...           ...
# 2239  2022                 VA            Virginia  8,683,619        20,624
# 2240  2022                 WA          Washington  7,785,786        29,504
# 2241  2022                 WV       West Virginia  1,775,156         5,213
# 2242  2022                 WI           Wisconsin  5,892,539        17,889
# 2243  2022                 WY             Wyoming    581,381         1,188
#
#      Homicide   Rape Robbery Aggravated_Assault Property_Crime Burglary  \
# 0          54    292     445               1203          23193     5616
# 1         496   1037    4127               9918         144372    48517
# 2         198    595    1626               5565          70949    21457
# 3         219   1120    4305               8884         177977    48916
# 4        2952  12239   75767              93129        1511021   496310
# ...       ...    ...     ...                ...            ...      ...
# 2239      641  2,791   3,360             13,832        148,845   10,944
# 2240      400  3,208   6,766             19,130        262,437   43,987
# 2241       95    909     210              3,999         23,663    3,561
# 2242      322  2,452   2,350             12,765         80,703    9,137
# 2243       15    373      48                752          9,590    1,257
#
#       Larceny Vehicle_Theft
# 0       15076          2501
# 1       83791         12064
# 2       45267          4225
# 3      116976         12085
# 4      847148        167563
# ...       ...           ...
# 2239  123,805        14,096
# 2240  168,550        49,900
# 2241   18,428         1,674
# 2242   58,211        13,355
# 2243    7,390           943
#
# [2244 rows x 13 columns]

# %%
crime_filtered_years= crime_filtered_years.replace(',', '', regex = True)

# %%
#changing and ensuring the types for each column's data
crime_filtered_years['Population'] = crime_filtered_years['Population'].astype(int)
crime_filtered_years['Rape'] = crime_filtered_years['Rape'].astype(int)
crime_filtered_years['Robbery'] = crime_filtered_years['Robbery'].astype(int)
crime_filtered_years['Aggravated_Assault'] = crime_filtered_years['Aggravated_Assault'].astype(int)
crime_filtered_years['Violent_Crime'] = crime_filtered_years['Violent_Crime'].astype(int)
crime_filtered_years['Homicide'] = crime_filtered_years['Homicide'].astype(int)
crime_filtered_years.dtypes
# Out:
# Year                   int64
# State_Abbreviation    object
# State_Name            object
# Population             int64
# Violent_Crime          int64
# Homicide               int64
# Rape                   int64
# Robbery                int64
# Aggravated_Assault     int64
# Property_Crime        object
# Burglary              object
# Larceny               object
# Vehicle_Theft         object
# dtype: object

# %%
crime_filtered_years.rename(columns={'State_Name': 'State'}, inplace=True)
crime_df = crime_filtered_years
crime_df
# Out:
#       Year State_Abbreviation               State  Population  Violent_Crime  \
# 0     1979                 AK              Alaska      406000           1994
# 1     1979                 AL             Alabama     3769000          15578
# 2     1979                 AR            Arkansas     2180000           7984
# 3     1979                 AZ             Arizona     2450000          14528
# 4     1979                 CA          California    22696000         184087
# ...    ...                ...                 ...         ...            ...
# 2239  2022                 VA            Virginia     8683619          20624
# 2240  2022                 WA          Washington     7785786          29504
# 2241  2022                 WV       West Virginia     1775156           5213
# 2242  2022                 WI           Wisconsin     5892539          17889
# 2243  2022                 WY             Wyoming      581381           1188
#
#       Homicide   Rape  Robbery  Aggravated_Assault Property_Crime Burglary  \
# 0           54    292      445                1203          23193     5616
# 1          496   1037     4127                9918         144372    48517
# 2          198    595     1626                5565          70949    21457
# 3          219   1120     4305                8884         177977    48916
# 4         2952  12239    75767               93129        1511021   496310
# ...        ...    ...      ...                 ...            ...      ...
# 2239       641   2791     3360               13832         148845    10944
# 2240       400   3208     6766               19130         262437    43987
# 2241        95    909      210                3999          23663     3561
# 2242       322   2452     2350               12765          80703     9137
# 2243        15    373       48                 752           9590     1257
#
#      Larceny Vehicle_Theft
# 0      15076          2501
# 1      83791         12064
# 2      45267          4225
# 3     116976         12085
# 4     847148        167563
# ...      ...           ...
# 2239  123805         14096
# 2240  168550         49900
# 2241   18428          1674
# 2242   58211         13355
# 2243    7390           943
#
# [2244 rows x 13 columns]
