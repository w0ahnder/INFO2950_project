# %%
import numpy as np
import pandas as pd

# %%
job_df = pd.read_csv('emp_table.csv')
job_df.head()
# Out:
#   Average Annual Unemployment Rates by State (see previous tab for Iowa's counties)  \
# 0                    U.S. Bureau of Labor Statistics
# 1  Local Area Unemployment Statistics and Current...
# 2                                 April 2019 release
# 3                                                NaN
# 4                                               Fips
#
#   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4       Area      1980.0      1981.0      1982.0      1983.0      1984.0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 31  Unnamed: 32  \
# 0         NaN         NaN         NaN  ...          NaN          NaN
# 1         NaN         NaN         NaN  ...          NaN          NaN
# 2         NaN         NaN         NaN  ...          NaN          NaN
# 3         NaN         NaN         NaN  ...          NaN          NaN
# 4      1985.0      1986.0      1987.0  ...       2009.0       2010.0
#
#    Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4       2011.0       2012.0       2013.0       2014.0       2015.0
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4       2016.0       2017.0       2018.0
#
# [5 rows x 41 columns]

# %%
job_df = job_df.loc[4:, :].reset_index(drop=True)
job_df.head()
# Out:
#   Average Annual Unemployment Rates by State (see previous tab for Iowa's counties)  \
# 0                                               Fips
# 1                                              00000
# 2                                              01000
# 3                                              02000
# 4                                              04000
#
#       Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0           Area      1980.0      1981.0      1982.0      1983.0      1984.0
# 1  United States         7.1         7.6         9.7         9.6         7.5
# 2        Alabama         8.9        10.6        14.1        13.8        11.0
# 3         Alaska         9.6         9.4         9.9         9.9         9.8
# 4        Arizona         6.6         6.2        10.1         8.8         5.2
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 31  Unnamed: 32  \
# 0      1985.0      1986.0      1987.0  ...       2009.0       2010.0
# 1         7.2         7.0         6.2  ...          9.3          9.6
# 2         9.2         9.7         8.1  ...         11.0         10.5
# 3         9.7        10.9        10.3  ...          7.7          7.9
# 4         6.3         6.9         6.5  ...          9.9         10.4
#
#    Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36  Unnamed: 37  \
# 0       2011.0       2012.0       2013.0       2014.0       2015.0
# 1          8.9          8.1          7.4          6.2          5.3
# 2          9.6          8.0          7.2          6.8          6.1
# 3          7.6          7.1          7.0          6.9          6.5
# 4          9.5          8.3          7.7          6.8          6.1
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40
# 0       2016.0       2017.0       2018.0
# 1          4.9          4.4          3.9
# 2          5.8          4.4          3.9
# 3          6.9          7.0          6.6
# 4          5.4          4.9          4.8
#
# [5 rows x 41 columns]

# %%
job_df = job_df.loc[:, ["Unnamed: 1", "Unnamed: 35","Unnamed: 36",
                        "Unnamed: 37", "Unnamed: 38", "Unnamed: 39", "Unnamed: 40"]]
job_df.head()
# Out:
#       Unnamed: 1  Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0           Area       2013.0       2014.0       2015.0       2016.0
# 1  United States          7.4          6.2          5.3          4.9
# 2        Alabama          7.2          6.8          6.1          5.8
# 3         Alaska          7.0          6.9          6.5          6.9
# 4        Arizona          7.7          6.8          6.1          5.4
#
#    Unnamed: 39  Unnamed: 40
# 0       2017.0       2018.0
# 1          4.4          3.9
# 2          4.4          3.9
# 3          7.0          6.6
# 4          4.9          4.8

# %%
job_df.rename(columns= {"Unnamed: 1": "Area", "Unnamed: 35": "2013", "Unnamed: 36": '2014',
                        "Unnamed: 37": '2015', "Unnamed: 38":'2016',
                        "Unnamed: 39":'2017', "Unnamed: 40":'2018'}, inplace=True)
job_df.head()
# Out:
#             Area    2013    2014    2015    2016    2017    2018
# 0           Area  2013.0  2014.0  2015.0  2016.0  2017.0  2018.0
# 1  United States     7.4     6.2     5.3     4.9     4.4     3.9
# 2        Alabama     7.2     6.8     6.1     5.8     4.4     3.9
# 3         Alaska     7.0     6.9     6.5     6.9     7.0     6.6
# 4        Arizona     7.7     6.8     6.1     5.4     4.9     4.8

# %%
job_df = job_df.loc[1:, :]
job_df.head()
# Out:
#             Area  2013  2014  2015  2016  2017  2018
# 1  United States   7.4   6.2   5.3   4.9   4.4   3.9
# 2        Alabama   7.2   6.8   6.1   5.8   4.4   3.9
# 3         Alaska   7.0   6.9   6.5   6.9   7.0   6.6
# 4        Arizona   7.7   6.8   6.1   5.4   4.9   4.8
# 5       Arkansas   7.2   6.0   5.0   4.0   3.7   3.7

# %%
job_df.reset_index(inplace=True, drop=True)
job_df.head()
# Out:
#             Area  2013  2014  2015  2016  2017  2018
# 0  United States   7.4   6.2   5.3   4.9   4.4   3.9
# 1        Alabama   7.2   6.8   6.1   5.8   4.4   3.9
# 2         Alaska   7.0   6.9   6.5   6.9   7.0   6.6
# 3        Arizona   7.7   6.8   6.1   5.4   4.9   4.8
# 4       Arkansas   7.2   6.0   5.0   4.0   3.7   3.7
